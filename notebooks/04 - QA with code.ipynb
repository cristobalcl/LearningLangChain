# %% [markdown]
# # LangChain - QA with code

# %% [markdown]
# ## Install dependencies

# %%
# !pip install "langchain[llms]>=0.0.218"
# !pip install chromadb
# !pip install sentence_transformers
# !pip install tiktoken
# !pip install GitPython
# !pip install python-dotenv
# Out:
# Collecting langchain[llms]>=0.0.218
#   Downloading langchain-0.0.221-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.2 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.9/site-packages (from langchain[llms]>=0.0.218) (1.23.3)
# Requirement already satisfied: PyYAML>=5.4.1 in /opt/conda/lib/python3.9/site-packages (from langchain[llms]>=0.0.218) (6.0)
# Collecting langchainplus-sdk>=0.0.17
#   Downloading langchainplus_sdk-0.0.19-py3-none-any.whl (25 kB)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting dataclasses-json<0.6.0,>=0.5.7
#   Downloading dataclasses_json-0.5.9-py3-none-any.whl (26 kB)
# Collecting openapi-schema-pydantic<2.0,>=1.2
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 41.5 MB/s eta 0:00:00
# Collecting tenacity<9.0.0,>=8.1.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting pydantic<2,>=1
#   Downloading pydantic-1.10.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 42.4 MB/s eta 0:00:0000:0100:01
# Collecting numexpr<3.0.0,>=2.8.4
#   Downloading numexpr-2.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.7/380.7 kB 40.8 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.9/site-packages (from langchain[llms]>=0.0.218) (2.28.1)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.2 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.9/site-packages (from langchain[llms]>=0.0.218) (1.4.41)
# Collecting openlm<0.0.6,>=0.0.5
#   Downloading openlm-0.0.5-py3-none-any.whl (10 kB)
# Collecting anthropic<0.3.0,>=0.2.6
#   Downloading anthropic-0.2.10-py3-none-any.whl (6.3 kB)
# Collecting manifest-ml<0.0.2,>=0.0.1
#   Downloading manifest_ml-0.0.1-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 18.0 MB/s eta 0:00:00
# Collecting torch<3,>=1
#   Downloading torch-2.0.1-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.8 MB/s eta 0:00:0000:0100:01
# Collecting cohere<4,>=3
#   Downloading cohere-3.10.0.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting nlpcloud<2,>=1
#   Downloading nlpcloud-1.0.43-py3-none-any.whl (4.5 kB)
# Collecting transformers<5,>=4
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 38.5 MB/s eta 0:00:0000:0100:01
# Collecting huggingface_hub<1,>=0
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 33.3 MB/s eta 0:00:00
# Collecting openllm>=0.1.19
#   Downloading openllm-0.1.19-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.7/184.7 kB 17.8 MB/s eta 0:00:00
# Collecting clarifai==9.1.0
#   Downloading clarifai-9.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 9.7 MB/s eta 0:00:00
# Collecting openai<1,>=0
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 138.6 kB/s eta 0:00:0000:01
# Collecting clarifai-grpc>=9.1.0
#   Downloading clarifai_grpc-9.5.0-py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.8/206.8 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[llms]>=0.0.218) (22.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[llms]>=0.0.218) (2.1.1)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 7.5 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 19.2 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 11.4 MB/s eta 0:00:00
# Collecting tokenizers
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 38.0 MB/s eta 0:00:0000:0100:01
# Collecting httpx
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3~=1.26 in /opt/conda/lib/python3.9/site-packages (from cohere<4,>=3->langchain[llms]>=0.0.218) (1.26.11)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 7.3 MB/s eta 0:00:00
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.9/site-packages (from huggingface_hub<1,>=0->langchain[llms]>=0.0.218) (2022.8.2)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.9/site-packages (from huggingface_hub<1,>=0->langchain[llms]>=0.0.218) (21.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.9/site-packages (from huggingface_hub<1,>=0->langchain[llms]>=0.0.218) (4.64.1)
# Collecting filelock
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from huggingface_hub<1,>=0->langchain[llms]>=0.0.218) (4.4.0)
# Requirement already satisfied: dill>=0.3.5 in /opt/conda/lib/python3.9/site-packages (from manifest-ml<0.0.2,>=0.0.1->langchain[llms]>=0.0.218) (0.3.5.1)
# Collecting sqlitedict>=2.0.0
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting redis>=4.3.1
#   Downloading redis-4.6.0-py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.1/241.1 kB 11.5 MB/s eta 0:00:00
# Collecting optimum
#   Downloading optimum-1.9.0-py3-none-any.whl (327 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.4/327.4 kB 43.6 MB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.9/136.9 kB 9.7 MB/s eta 0:00:00
# Collecting cattrs>=23.1.0
#   Downloading cattrs-23.1.2-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 7.1 MB/s eta 0:00:00
# Collecting tabulate[widechars]>=0.9.0
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting inflection
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting bentoml[grpc,io]>=1.0.22
#   Downloading bentoml-1.0.23-py3-none-any.whl (996 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.3/996.3 kB 40.5 MB/s eta 0:00:00
# Collecting attrs>=17.3.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2->langchain[llms]>=0.0.218) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2->langchain[llms]>=0.0.218) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain[llms]>=0.0.218) (1.1.3)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 20.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 11.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from torch<3,>=1->langchain[llms]>=0.0.218) (3.1.2)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from torch<3,>=1->langchain[llms]>=0.0.218) (1.11.1)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 28.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu11==2.14.3
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu11==11.7.91
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 13.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 37.2 MB/s eta 0:00:0000:0100:01
# Collecting triton==2.0.0
#   Downloading triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 15.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 3.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from torch<3,>=1->langchain[llms]>=0.0.218) (2.8.7)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 6.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<3,>=1->langchain[llms]>=0.0.218) (65.4.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<3,>=1->langchain[llms]>=0.0.218) (0.37.1)
# Collecting cmake
#   Downloading cmake-3.26.4-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 25.1 MB/s eta 0:00:0000:0100:01
# Collecting lit
#   Downloading lit-16.0.6.tar.gz (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 14.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.0 MB/s eta 0:00:0000:01
# Collecting regex!=2019.12.17
#   Downloading regex-2023.6.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (769 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.9/769.9 kB 31.9 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (8.1.3)
# Collecting opentelemetry-instrumentation-aiohttp-client==0.38b0
#   Downloading opentelemetry_instrumentation_aiohttp_client-0.38b0-py3-none-any.whl (11 kB)
# Collecting packaging>=20.9
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 7.8 MB/s eta 0:00:00
# Collecting pathspec
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Collecting opentelemetry-util-http==0.38b0
#   Downloading opentelemetry_util_http-0.38b0-py3-none-any.whl (6.7 kB)
# Collecting opentelemetry-instrumentation==0.38b0
#   Downloading opentelemetry_instrumentation-0.38b0-py3-none-any.whl (24 kB)
# Collecting schema
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Collecting click-option-group
#   Downloading click_option_group-0.5.6-py3-none-any.whl (12 kB)
# Collecting pip-tools>=6.6.2
#   Downloading pip_tools-6.14.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 5.7 MB/s eta 0:00:00
# Collecting circus!=0.17.2,>=0.17.0
#   Downloading circus-0.18.0-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 22.4 MB/s eta 0:00:00
# Collecting opentelemetry-semantic-conventions==0.38b0
#   Downloading opentelemetry_semantic_conventions-0.38b0-py3-none-any.whl (26 kB)
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 7.3 MB/s eta 0:00:00
# Collecting simple-di>=0.1.4
#   Downloading simple_di-0.1.5-py3-none-any.whl (9.8 kB)
# Collecting opentelemetry-api==1.17.0
#   Downloading opentelemetry_api-1.17.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 9.4 MB/s eta 0:00:00
# Collecting starlette<0.29,>=0.13.5
#   Downloading starlette-0.28.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: prometheus-client>=0.10.0 in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (0.14.1)
# Collecting opentelemetry-sdk==1.17.0
#   Downloading opentelemetry_sdk-1.17.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (5.9.2)
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 22.8 MB/s eta 0:00:00
# Collecting watchfiles>=0.15.0
#   Downloading watchfiles-0.19.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.0 MB/s eta 0:00:0000:01
# Collecting pip-requirements-parser>=31.2.0
#   Downloading pip_requirements_parser-32.0.1-py3-none-any.whl (35 kB)
# Collecting rich>=11.2.0
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 15.4 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.38b0
#   Downloading opentelemetry_instrumentation_asgi-0.38b0-py3-none-any.whl (13 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (2.8.2)
# Collecting pynvml<12
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: python-json-logger in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (2.0.1)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (2.2.0)
# Collecting deepmerge
#   Downloading deepmerge-1.1.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (4.21.7)
# Collecting opentelemetry-instrumentation-grpc==0.38b0
#   Downloading opentelemetry_instrumentation_grpc-0.38b0-py3-none-any.whl (25 kB)
# Collecting grpcio-health-checking
#   Downloading grpcio_health_checking-1.56.0-py3-none-any.whl (8.5 kB)
# Collecting grpcio
#   Downloading grpcio-1.56.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 34.6 MB/s eta 0:00:0000:0100:01
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata~=6.0.0
#   Downloading importlib_metadata-6.0.1-py3-none-any.whl (21 kB)
# Collecting wrapt<2.0.0,>=1.0.0
#   Downloading wrapt-1.15.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 5.4 MB/s eta 0:00:00
# Collecting asgiref~=3.0
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Collecting googleapis-common-protos>=1.53.0
#   Downloading googleapis_common_protos-1.59.1-py2.py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 31.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->torch<3,>=1->langchain[llms]>=0.0.218) (2.1.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from tabulate[widechars]>=0.9.0->openllm>=0.1.19->langchain[llms]>=0.0.218) (0.2.5)
# Collecting accelerate>=0.20.2
#   Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 33.2 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.2-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.9/site-packages (from httpx->anthropic<0.3.0,>=0.2.6->langchain[llms]>=0.0.218) (1.3.0)
# Collecting datasets
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 51.5 MB/s eta 0:00:00
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->torch<3,>=1->langchain[llms]>=0.0.218) (1.2.1)
# Requirement already satisfied: pyzmq>=17.0 in /opt/conda/lib/python3.9/site-packages (from circus!=0.17.2,>=0.17.0->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (24.0.1)
# Requirement already satisfied: tornado>=5.0.2 in /opt/conda/lib/python3.9/site-packages (from circus!=0.17.2,>=0.17.0->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (6.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/conda/lib/python3.9/site-packages (from httpcore<0.18.0,>=0.15.0->httpx->anthropic<0.3.0,>=0.2.6->langchain[llms]>=0.0.218) (3.6.1)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.9/site-packages (from pip-requirements-parser>=31.2.0->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (3.0.9)
# Requirement already satisfied: pip>=22.2 in /opt/conda/lib/python3.9/site-packages (from pip-tools>=6.6.2->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (22.2.2)
# Collecting build
#   Downloading build-0.10.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: tomli in /opt/conda/lib/python3.9/site-packages (from pip-tools>=6.6.2->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (2.0.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.9/site-packages (from rich>=11.2.0->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (2.13.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 9.1 MB/s eta 0:00:00
# Collecting protobuf
#   Downloading protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.0 MB/s eta 0:00:00
# Collecting sentencepiece!=0.1.92,>=0.1.91
#   Downloading sentencepiece-0.1.99-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.8 MB/s eta 0:00:0000:01
# Collecting filetype
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (9.2.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (1.5.0)
# Collecting pyarrow
#   Downloading pyarrow-12.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.0/39.0 MB 23.4 MB/s eta 0:00:0000:0100:01
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.7 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 21.3 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: six~=1.10 in /opt/conda/lib/python3.9/site-packages (from fs->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (1.16.0)
# Collecting appdirs~=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting grpcio-health-checking
#   Downloading grpcio_health_checking-1.54.2-py3-none-any.whl (8.5 kB)
#   Downloading grpcio_health_checking-1.54.0-py3-none-any.whl (8.5 kB)
#   Downloading grpcio_health_checking-1.53.1-py3-none-any.whl (8.5 kB)
#   Downloading grpcio_health_checking-1.53.0-py3-none-any.whl (8.5 kB)
#   Downloading grpcio_health_checking-1.51.3-py3-none-any.whl (8.5 kB)
#   Downloading grpcio_health_checking-1.51.1-py3-none-any.whl (8.5 kB)
#   Downloading grpcio_health_checking-1.50.0-py3-none-any.whl (17 kB)
#   Downloading grpcio_health_checking-1.49.1-py3-none-any.whl (17 kB)
#   Downloading grpcio_health_checking-1.48.2-py3-none-any.whl (18 kB)
# Collecting contextlib2>=0.5.5
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata~=6.0.0->opentelemetry-api==1.17.0->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (3.9.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting dill>=0.3.5
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas->bentoml[grpc,io]>=1.0.22->openllm>=0.1.19->langchain[llms]>=0.0.218) (2022.4)
# Building wheels for collected packages: cohere, sqlitedict, lit
#   Building wheel for cohere (setup.py) ... done
#   Created wheel for cohere: filename=cohere-3.10.0-cp39-cp39-linux_x86_64.whl size=18294 sha256=554c102db648af5045cc7c40538212d9672b25e46aab82e6fd2fc443e224b627
#   Stored in directory: /home/jovyan/.cache/pip/wheels/45/ed/84/48ab442187d3a7276e1c045360a2496f33493adafeaa88d201
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16864 sha256=5d107e0b18d5d9d914f2598f79e1ed66d953dcd0e030a169b30c6fe5d387abe6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f6/48/c4/942f7a1d556fddd2348cb9ac262f251873dfd8a39afec5678e
#   Building wheel for lit (pyproject.toml) ... done
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93582 sha256=fec34dcbb3667a6e51ff28051376c5a1addd9af1a90be30806d0afc95a738f47
#   Stored in directory: /home/jovyan/.cache/pip/wheels/a5/36/d6/cac2e6fb891889b33a548f2fddb8b4b7726399aaa2ed32b188
# Successfully built cohere sqlitedict lit
# Installing collected packages: tokenizers, sqlitedict, sentencepiece, safetensors, lit, filetype, deepmerge, cmake, appdirs, xxhash, wrapt, tenacity, tabulate, simple-di, regex, python-multipart, pyproject_hooks, pynvml, pydantic, pyarrow, protobuf, pathspec, packaging, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, numexpr, mypy-extensions, multidict, mdurl, inflection, importlib-metadata, humanfriendly, h11, grpcio, fs, frozenlist, filelock, exceptiongroup, dill, contextlib2, click-option-group, circus, attrs, async-timeout, asgiref, yarl, watchfiles, uvicorn, typing-inspect, starlette, schema, redis, pip-requirements-parser, openlm, openapi-schema-pydantic, nvidia-cusolver-cu11, nvidia-cudnn-cu11, nlpcloud, multiprocess, marshmallow, markdown-it-py, langchainplus-sdk, huggingface_hub, httpcore, grpcio-health-checking, googleapis-common-protos, deprecated, coloredlogs, cohere, cattrs, build, aiosignal, transformers, rich, pip-tools, opentelemetry-api, marshmallow-enum, manifest-ml, httpx, clarifai-grpc, aiohttp, opentelemetry-sdk, opentelemetry-instrumentation, openai, dataclasses-json, clarifai, anthropic, opentelemetry-instrumentation-grpc, opentelemetry-instrumentation-asgi, opentelemetry-instrumentation-aiohttp-client, langchain, datasets, bentoml, triton, torch, accelerate, optimum, openllm
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.21.7
#     Uninstalling protobuf-4.21.7:
#       Successfully uninstalled protobuf-4.21.7
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.8.3
#     Uninstalling numexpr-2.8.3:
#       Successfully uninstalled numexpr-2.8.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.4
#     Uninstalling importlib-metadata-4.11.4:
#       Successfully uninstalled importlib-metadata-4.11.4
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# Successfully installed accelerate-0.20.3 aiohttp-3.8.4 aiosignal-1.3.1 anthropic-0.2.10 appdirs-1.4.4 asgiref-3.7.2 async-timeout-4.0.2 attrs-23.1.0 bentoml-1.0.23 build-0.10.0 cattrs-23.1.2 circus-0.18.0 clarifai-9.1.0 clarifai-grpc-9.5.0 click-option-group-0.5.6 cmake-3.26.4 cohere-3.10.0 coloredlogs-15.0.1 contextlib2-21.6.0 dataclasses-json-0.5.9 datasets-2.13.1 deepmerge-1.1.0 deprecated-1.2.14 dill-0.3.6 exceptiongroup-1.1.1 filelock-3.12.2 filetype-1.2.0 frozenlist-1.3.3 fs-2.4.16 googleapis-common-protos-1.59.1 grpcio-1.56.0 grpcio-health-checking-1.48.2 h11-0.14.0 httpcore-0.17.2 httpx-0.24.1 huggingface_hub-0.15.1 humanfriendly-10.0 importlib-metadata-6.0.1 inflection-0.5.1 langchain-0.0.221 langchainplus-sdk-0.0.19 lit-16.0.6 manifest-ml-0.0.1 markdown-it-py-3.0.0 marshmallow-3.19.0 marshmallow-enum-1.5.1 mdurl-0.1.2 multidict-6.0.4 multiprocess-0.70.14 mypy-extensions-1.0.0 nlpcloud-1.0.43 numexpr-2.8.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 openai-0.27.8 openapi-schema-pydantic-1.2.4 openllm-0.1.19 openlm-0.0.5 opentelemetry-api-1.17.0 opentelemetry-instrumentation-0.38b0 opentelemetry-instrumentation-aiohttp-client-0.38b0 opentelemetry-instrumentation-asgi-0.38b0 opentelemetry-instrumentation-grpc-0.38b0 opentelemetry-sdk-1.17.0 opentelemetry-semantic-conventions-0.38b0 opentelemetry-util-http-0.38b0 optimum-1.9.0 orjson-3.9.1 packaging-23.1 pathspec-0.11.1 pip-requirements-parser-32.0.1 pip-tools-6.14.0 protobuf-3.20.3 pyarrow-12.0.1 pydantic-1.10.10 pynvml-11.5.0 pyproject_hooks-1.0.0 python-multipart-0.0.6 redis-4.6.0 regex-2023.6.3 rich-13.4.2 safetensors-0.3.1 schema-0.7.5 sentencepiece-0.1.99 simple-di-0.1.5 sqlitedict-2.1.0 starlette-0.28.0 tabulate-0.9.0 tenacity-8.2.2 tokenizers-0.13.3 torch-2.0.1 transformers-4.30.2 triton-2.0.0 typing-inspect-0.9.0 uvicorn-0.22.0 watchfiles-0.19.0 wrapt-1.15.0 xxhash-3.2.0 yarl-1.9.2
# Collecting chromadb
#   Downloading chromadb-0.3.26-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 2.7 MB/s eta 0:00:0000:01
# Collecting posthog>=2.4.0
#   Downloading posthog-3.0.1-py2.py3-none-any.whl (37 kB)
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.9/site-packages (from chromadb) (1.23.3)
# Collecting hnswlib>=0.7
#   Downloading hnswlib-0.7.0.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting clickhouse-connect>=0.5.7
#   Downloading clickhouse_connect-0.6.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (970 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 970.7/970.7 kB 17.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas>=1.3 in /opt/conda/lib/python3.9/site-packages (from chromadb) (1.5.0)
# Collecting pulsar-client>=3.1.0
#   Downloading pulsar_client-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 5.2 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/conda/lib/python3.9/site-packages (from chromadb) (0.13.3)
# Collecting typing-extensions>=4.5.0
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.15.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 36.6 MB/s eta 0:00:0000:0100:01
# Collecting fastapi>=0.85.1
#   Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.7 MB/s eta 0:00:00
# Collecting overrides>=7.3.1
#   Downloading overrides-7.3.1-py3-none-any.whl (17 kB)
# Collecting duckdb>=0.7.1
#   Downloading duckdb-0.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 11.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /opt/conda/lib/python3.9/site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: pydantic>=1.9 in /opt/conda/lib/python3.9/site-packages (from chromadb) (1.10.10)
# Requirement already satisfied: requests>=2.28 in /opt/conda/lib/python3.9/site-packages (from chromadb) (2.28.1)
# Requirement already satisfied: lz4 in /opt/conda/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (4.0.0)
# Collecting zstandard
#   Downloading zstandard-0.21.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 14.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3>=1.26 in /opt/conda/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (1.26.11)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2022.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2022.9.24)
# Collecting starlette<0.28.0,>=0.27.0
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: coloredlogs in /opt/conda/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.1)
# Collecting flatbuffers
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.3->chromadb) (2.8.2)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.9/site-packages (from requests>=2.28->chromadb) (2.1.1)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.3)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.17.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 27.9 MB/s eta 0:00:0000:0100:01
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting websockets>=10.4
#   Downloading websockets-11.0.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.7/129.7 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Collecting httptools>=0.5.0
#   Downloading httptools-0.5.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 kB 44.2 MB/s eta 0:00:00
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.9/site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb) (3.6.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb) (1.3.0)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.7.0-cp39-cp39-linux_x86_64.whl size=187443 sha256=12d3e492fd04c62fe6308e13e044fc1be7a68b9f6d525d3f6ee14a6eacf62f3a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ba/26/61/fface6c407f56418b3140cd7645917f20ba6b27d4e32b2bd20
# Successfully built hnswlib
# Installing collected packages: monotonic, flatbuffers, duckdb, zstandard, websockets, uvloop, typing-extensions, tqdm, python-dotenv, pulsar-client, overrides, httptools, hnswlib, backoff, starlette, posthog, onnxruntime, clickhouse-connect, fastapi, chromadb
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.28.0
#     Uninstalling starlette-0.28.0:
#       Successfully uninstalled starlette-0.28.0
# Successfully installed backoff-2.2.1 chromadb-0.3.26 clickhouse-connect-0.6.4 duckdb-0.8.1 fastapi-0.99.1 flatbuffers-23.5.26 hnswlib-0.7.0 httptools-0.5.0 monotonic-1.6 onnxruntime-1.15.1 overrides-7.3.1 posthog-3.0.1 pulsar-client-3.2.0 python-dotenv-1.0.0 starlette-0.27.0 tqdm-4.65.0 typing-extensions-4.7.1 uvloop-0.17.0 websockets-11.0.3 zstandard-0.21.0
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.9 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.9/site-packages (from sentence_transformers) (4.30.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from sentence_transformers) (2.0.1)
# Collecting torchvision
#   Downloading torchvision-0.15.2-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 29.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (from sentence_transformers) (1.23.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.9/site-packages (from sentence_transformers) (1.1.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from sentence_transformers) (1.9.1)
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.7 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.9/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /opt/conda/lib/python3.9/site-packages (from sentence_transformers) (0.15.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.28.1)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2022.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (8.5.0.96)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (10.9.0.58)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.4.91)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (11.10.3.66)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (2.14.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.99)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (2.8.7)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (10.2.10.91)
# Requirement already satisfied: triton==2.0.0 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (11.4.0.1)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.91)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /opt/conda/lib/python3.9/site-packages (from torch>=1.6.0->sentence_transformers) (11.7.99)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (65.4.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (0.37.1)
# Requirement already satisfied: lit in /opt/conda/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: cmake in /opt/conda/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: click in /opt/conda/lib/python3.9/site-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.9/site-packages (from torchvision->sentence_transformers) (9.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.2.1)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=5c4035f2e5c2caeea9f42c2162255a13cacb0311d98b03fdb933b614d61b9375
#   Stored in directory: /home/jovyan/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence_transformers
# Installing collected packages: nltk, torchvision, sentence_transformers
# Successfully installed nltk-3.8.1 sentence_transformers-2.2.2 torchvision-0.15.2
# Collecting tiktoken
#   Downloading tiktoken-0.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.9/site-packages (from tiktoken) (2.28.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.9/site-packages (from tiktoken) (2023.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.1.1)
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.4.0
# Collecting GitPython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.8 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, GitPython
# Successfully installed GitPython-3.1.31 gitdb-4.0.10 smmap-5.0.0
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.9/site-packages (1.0.0)

# %% [markdown]
# ## Load environment variables
#
# Change the path if necessary (read `README.md` first and follow the instructions to setup the `.env` file):

# %%
import os
os.chdir("/home/jovyan/work/")

# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# ## Load a repository

# %%
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import LanguageParser
from langchain.text_splitter import Language
from git import Repo

# %%
repo = Repo.clone_from(
    "https://github.com/hwchase17/langchain", to_path="/tmp/test_repo"
)

# %%
loader = GenericLoader.from_filesystem(
    "/tmp/test_repo/langchain",
    glob="**/*",
    suffixes=[".py"],
    parser=LanguageParser(language=Language.PYTHON, parser_threshold=500)
)
documents = loader.load()
len(documents)
# Out:
# 1071

# %% [markdown]
# ## Index

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
python_splitter = RecursiveCharacterTextSplitter.from_language(language=Language.PYTHON, chunk_size=2000, chunk_overlap=200)
texts = python_splitter.split_documents(documents)
len(texts)
# Out:
# 2934

# %%
embeddings = OpenAIEmbeddings(disallowed_special=())

db = Chroma.from_documents(texts, embeddings)

# %%
retriever = db.as_retriever(
    search_type="mmr",  # You can also experiment with "similarity"
    search_kwargs={"k": 8},
)

# %% [markdown]
# ## Setup agent

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain

# %%
llm = ChatOpenAI(temperature=0)

# %%
qa = ConversationalRetrievalChain.from_llm(llm, retriever=retriever)

# %% [markdown]
# ## Tests

# %%
chat_history = []

# %%
question = "How can I load a source code as documents, for a QA over code, spliting the code in classes and functions?"
result = qa({"question": question, "chat_history": chat_history})
chat_history.append((question, result["answer"]))
print(result["answer"])
# Out:
# To load a source code as documents for a QA over code, splitting the code into classes and functions, you can use the `LanguageParser` class from the `langchain.text_splitter` module. Here's an example:
#
# ```python
# from langchain.text_splitter import Language
# from langchain.document_loaders.generic import GenericLoader
# from langchain.document_loaders.parsers import LanguageParser
#
# loader = GenericLoader.from_filesystem(
#     "./code",
#     glob="**/*",
#     suffixes=[".py", ".js"],
#     parser=LanguageParser()
# )
# docs = loader.load()
# ```
#
# In this example, the `GenericLoader` is used to load the source code files from the specified directory (`"./code"`) with the specified file extensions (`.py` and `.js`). The `LanguageParser` is used as the parser to split the code into separate documents based on classes and functions. The resulting documents are stored in the `docs` variable.
#
# You can also specify the language explicitly by passing the `language` parameter to the `LanguageParser` constructor. For example, to parse Python code, you can use `Language.PYTHON`:
#
# ```python
# loader = GenericLoader.from_filesystem(
#     "./code",
#     glob="**/*",
#     suffixes=[".py"],
#     parser=LanguageParser(language=Language.PYTHON)
# )
# ```
#
# Note that the `LanguageParser` currently supports Python and JavaScript as the supported languages for code parsing.
